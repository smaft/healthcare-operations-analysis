# %%
##  Data Loading

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/encounters.csv")

# %%
df.head()
# Out:
#                                      Id                 START  \
# 0  748f8357-6cc7-551d-f31a-32fa2cf84126  2019-02-17T05:07:38Z
# 1  5a4735ae-423f-6563-28ab-b3d11b49b2d4  2019-03-24T05:07:38Z
# 2  0bee1ce6-3e2c-5506-f71c-a7ba8f64a3d3  2019-05-26T05:07:38Z
# 3  6e93bcf9-45a4-8528-0120-1c1eaa930faf  2019-07-28T05:07:38Z
# 4  8b6787c3-4316-a0cb-899d-4746525c319f  2019-10-27T05:07:38Z
#
#                    STOP                               PATIENT  \
# 0  2019-02-17T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 1  2019-03-24T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 2  2019-05-26T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 3  2019-07-28T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
# 4  2019-10-27T05:22:38Z  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85
#
#                            ORGANIZATION                              PROVIDER  \
# 0  f7ae497d-8dc6-3721-9402-43b621a4e7d2  82608ebb-037c-3cef-9d34-3736d69b29e8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61459 entries, 0 to 61458
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   61459 non-null  object
#  1   START                61459 non-null  object
#  2   STOP                 61459 non-null  object
#  3   PATIENT              61459 non-null  object
#  4   ORGANIZATION         61459 non-null  object
#  5   PROVIDER             61459 non-null  object
#  6   PAYER                61459 non-null  object
#  7   ENCOUNTERCLASS       61459 non-null  object
#  8   CODE                 61459 non-null  int64
#  9   DESCRIPTION          61459 non-null  object
#  10  BASE_ENCOUNTER_COST  61459 non-null  float64
#  11  TOTAL_CLAIM_COST     61459 non-null  float64
#  12  PAYER_COVERAGE       61459 non-null  float64
#  13  REASONCODE           15957 non-null  float64
#  14  REASONDESCRIPTION    15957 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Id                         0
# START                      0
# STOP                       0
# PATIENT                    0
# ORGANIZATION               0
# PROVIDER                   0
# PAYER                      0
# ENCOUNTERCLASS             0
# CODE                       0
# DESCRIPTION                0
# BASE_ENCOUNTER_COST        0
# TOTAL_CLAIM_COST           0
# PAYER_COVERAGE             0
# REASONCODE             45502
# REASONDESCRIPTION      45502
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe(include="all")
# Out:
#                                           Id                 START  \
# count                                  61459                 61459
# unique                                 61459                 58419
# top     748f8357-6cc7-551d-f31a-32fa2cf84126  1931-08-04T21:04:17Z
# freq                                       1                    11
# mean                                     NaN                   NaN
# std                                      NaN                   NaN
# min                                      NaN                   NaN
# 25%                                      NaN                   NaN
# 50%                                      NaN                   NaN
# 75%                                      NaN                   NaN
# max                                      NaN                   NaN
#
#                         STOP                               PATIENT  \
# count                  61459                                 61459
# ...

# %%
## Initial data quality checks were performed to assess missing values,duplicates, and variable distributions.

# %%
df = df.dropna(subset=["START", "STOP"])

# %%
df["START"] = pd.to_datetime(df["START"])
df["STOP"] = pd.to_datetime(df["STOP"])

# %%
df = df.drop_duplicates()

# %%
df["service_duration_min"] = (
    df["STOP"] - df["START"]
).dt.total_seconds() / 60

# %%
df = df[df["service_duration_min"] > 0]

# %%
df.to_csv("../data/processed/encounters_cleaned.csv", index=False)
